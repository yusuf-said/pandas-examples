# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('/home/yusuf/Masaüstü/pandas-examples/pandas-tutorials/data/world_population.csv')
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
df.describe()
# Out:
#              Rank  2022 Population  2020 Population  2015 Population  \
# count  234.000000     2.300000e+02     2.330000e+02     2.300000e+02
# mean   117.500000     3.463225e+07     3.360071e+07     3.206600e+07
# std     67.694165     1.378892e+08     1.358732e+08     1.315071e+08
# min      1.000000     5.100000e+02     5.200000e+02     5.640000e+02
# 25%     59.250000     4.197385e+05     4.064710e+05     3.942950e+05
# 50%    117.500000     5.762857e+06     5.456681e+06     5.244415e+06
# 75%    175.750000     2.265372e+07     2.152263e+07     1.973085e+07
# max    234.000000     1.425887e+09     1.424930e+09     1.393715e+09
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count     2.270000e+02     2.270000e+02     2.290000e+02     2.290000e+02
# mean      3.027016e+07     2.684050e+07     1.933046e+07     1.628288e+07
# std       1.260742e+08     1.133525e+08     8.130962e+07     6.934547e+07
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country                      234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              230 non-null    float64
#  6   2020 Population              233 non-null    float64
#  7   2015 Population              230 non-null    float64
#  8   2010 Population              227 non-null    float64
#  9   2000 Population              227 non-null    float64
#  10  1990 Population              229 non-null    float64
#  11  1980 Population              229 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# Rank                           0
# CCA3                           0
# Country                        0
# Capital                        0
# Continent                      0
# 2022 Population                4
# 2020 Population                1
# 2015 Population                4
# 2010 Population                7
# 2000 Population                7
# 1990 Population                5
# 1980 Population                5
# 1970 Population                4
# Area (km²)                     2
# Density (per km²)              4
# Growth Rate                    2
# World Population Percentage    0
# dtype: int64

# %%
duplicated_area = df[df.duplicated('Area (km²)', keep=False)]

# %%
duplicated_area
# Out:
#      Rank CCA3           Country   Capital      Continent  2022 Population  \
# 142   225  NRU             Nauru     Yaren        Oceania          12668.0
# 173   228  BLM  Saint Barthelemy  Gustavia  North America          10967.0
# 183    72  SEN           Senegal     Dakar         Africa       17316449.0
# 227    51  VEN         Venezuela   Caracas  South America       28301696.0
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# 142          12315.0          11185.0          10241.0          10377.0
# 173          10681.0           9643.0           8988.0           7082.0
# 183       16436119.0       14356181.0       12530121.0        9704287.0
# 227       28490453.0       30529716.0       28715022.0              NaN
#
#      1990 Population  1980 Population  1970 Population  Area (km²)  \
# 142           9598.0           7635.0           6663.0        21.0
# 173           5168.0           2983.0           2417.0        21.0
# ...

# %%
df.sort_values(by='2022 Population',ascending=True).head(10)
# Out:
#      Rank CCA3                    Country       Capital      Continent  \
# 226   234  VAT               Vatican City  Vatican City         Europe
# 209   233  TKL                    Tokelau      Nukunonu        Oceania
# 150   232  NIU                       Niue         Alofi        Oceania
# 64    231  FLK           Falkland Islands       Stanley  South America
# 137   230  MSR                 Montserrat        Brades  North America
# 177   229  SPM  Saint Pierre and Miquelon  Saint-Pierre  North America
# 173   228  BLM           Saint Barthelemy      Gustavia  North America
# 216   227  TUV                     Tuvalu      Funafuti        Oceania
# 229   226  WLF          Wallis and Futuna      Mata-Utu        Oceania
# 142   225  NRU                      Nauru         Yaren        Oceania
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 226            510.0            520.0            564.0            596.0
# ...

# %%
df.sort_values(by='World Population Percentage',ascending=True).head(10)
# Out:
#     Rank CCA3                 Country           Capital      Continent  \
# 3    213  ASM          American Samoa         Pago Pago        Oceania
# 7    201  ATG     Antigua and Barbuda      Saint John’s  North America
# 6    224  AIA                Anguilla        The Valley  North America
# 4    203  AND                 Andorra  Andorra la Vella         Europe
# 10   198  ABW                   Aruba        Oranjestad  North America
# 28   221  VGB  British Virgin Islands         Road Town  North America
# 22   206  BMU                 Bermuda          Hamilton  North America
# 17   186  BRB                Barbados        Bridgetown  North America
# 48   189  CUW                 Curacao        Willemstad  North America
# 53   204  DMA                Dominica            Roseau  North America
#
#     2022 Population  2020 Population  2015 Population  2010 Population  \
# 3           44273.0          46189.0          51368.0          54849.0
# ...

# %%
df.sort_values(by='Growth Rate',ascending=False).head(10)
# Out:
#      Rank CCA3   Country     Capital Continent  2022 Population  \
# 133   135  MDA   Moldova    Chisinau    Europe        3272996.0
# 164    37  POL    Poland      Warsaw    Europe       39857145.0
# 148    54  NER     Niger      Niamey    Africa       26207977.0
# 202    60  SYR     Syria    Damascus      Asia       22125249.0
# 189   116  SVK  Slovakia  Bratislava    Europe        5643453.0
# 55     15  COD  DR Congo    Kinshasa    Africa       99010212.0
# 130   182  MYT   Mayotte   Mamoudzou    Africa         326101.0
# 39     69  TCD      Chad   N'Djamena    Africa       17723315.0
# 5      42  AGO    Angola      Luanda    Africa       35588987.0
# 124    59  MLI      Mali      Bamako    Africa       22593590.0
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# 133        3084847.0        3277388.0        3678186.0        4251573.0
# 164       38428366.0       38553146.0       38597353.0       38504431.0
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                                  Rank  2022 Population  2020 Population  \
# Rank                         1.000000        -0.357989        -0.356283
# 2022 Population             -0.357989         1.000000         0.999946
# 2020 Population             -0.356283         0.999946         1.000000
# 2015 Population             -0.352850         0.999492         0.999764
# 2010 Population             -0.350009         0.998633         0.999108
# 2000 Population             -0.342095         0.994602         0.995582
# 1990 Population             -0.333014         0.991124         0.992557
# 1980 Population             -0.328620         0.986675         0.988392
# 1970 Population             -0.335737         0.973135         0.975245
# Area (km²)                  -0.384854         0.452812         0.454902
# Density (per km²)            0.128994        -0.028761        -0.027802
# Growth Rate                 -0.220197        -0.022059        -0.025976
# ...

# %%
plt.figure(figsize=(12, 12))

sns.heatmap(df.corr(numeric_only=True),annot=True)


plt.show()

# %%
df.groupby(by='Continent').mean(numeric_only=True).sort_values(by='2022 Population')
# Out:
#                      Rank  2022 Population  2020 Population  2015 Population  \
# Continent
# Oceania        188.521739     2.046386e+06     1.910149e+06     1.756664e+06
# North America  160.925000     1.500740e+07     1.485591e+07     1.425960e+07
# Europe         124.500000     1.505537e+07     1.491584e+07     1.502745e+07
# Africa          92.157895     2.545588e+07     2.387144e+07     2.141970e+07
# South America   97.571429     3.120119e+07     3.082357e+07     2.950960e+07
# Asia            77.560000     9.632739e+07     9.495513e+07     8.916500e+07
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# Oceania           1.613164e+06     1.357512e+06     1.162775e+06
# North America     1.356802e+07     1.215174e+07     1.053166e+07
# Europe            1.471228e+07     1.481769e+07     1.478520e+07
# Africa            1.889820e+07     1.459837e+07     1.137696e+07
# South America     2.678940e+07     2.501589e+07     2.122474e+07
# ...

# %%
df[df['Continent'].str.contains('Oceania')]
# Out:
#      Rank CCA3                   Country       Capital Continent  \
# 3     213  ASM            American Samoa     Pago Pago   Oceania
# 11     55  AUS                 Australia      Canberra   Oceania
# 44    223  COK              Cook Islands        Avarua   Oceania
# 66    162  FJI                      Fiji          Suva   Oceania
# 70    183  PYF          French Polynesia       Papeete   Oceania
# 81    191  GUM                      Guam       Hagåtña   Oceania
# 107   192  KIR                  Kiribati        Tarawa   Oceania
# 126   215  MHL          Marshall Islands        Majuro   Oceania
# 132   194  FSM                Micronesia       Palikir   Oceania
# 142   225  NRU                     Nauru         Yaren   Oceania
# 145   185  NCL             New Caledonia        Nouméa   Oceania
# 146   123  NZL               New Zealand    Wellington   Oceania
# 150   232  NIU                      Niue         Alofi   Oceania
# ...

# %%
df2 = df.groupby(by='Continent')[['1970 Population',
       '1980 Population', '1990 Population', '2000 Population',
       '2010 Population', '2015 Population', '2020 Population',
       '2022 Population']].mean(numeric_only=True).sort_values(by='2022 Population',ascending=False)

# %%
df2.plot()
# Out:
# <Axes: xlabel='Continent'>

# %%
plt.figure(figsize=(30,100))
df3 = df2.transpose()
plt.tight_layout()
df3.plot()
# Out:
# <Axes: >

# %%
df.select_dtypes(include='float')
# Out:
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# 2         44903225.0       43451666.0       39543154.0       35856344.0
# 3            44273.0          46189.0          51368.0          54849.0
# 4            79824.0          77700.0          71746.0          71519.0
# ..               ...              ...              ...              ...
# 229          11572.0          11655.0          12182.0          13142.0
# 230         575986.0         556048.0         491824.0         413296.0
# 231       33696614.0       32284046.0       28516545.0       24743946.0
# 232       20017675.0       18927715.0              NaN       13792086.0
# 233       16320537.0       15669666.0       14154937.0       12839771.0
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# ...

# %%
df.boxplot(figsize=(20,10))
# Out:
# <Axes: >
